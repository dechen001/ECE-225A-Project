# %%
# importing panda library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import sklearn
import sklearn.preprocessing as preprocessing

# %%
df = pd.read_csv('./ndata.csv')

# %% [markdown]
# # Potential association between variables

# %%
df
# Out:
#       Hospital Ownership  Emergency Services  Mortality national comparison  \
# 0                    0.0                 1.0                            0.5
# 1                    0.0                 1.0                            0.0
# 2                    0.0                 1.0                            0.0
# 3                    1.0                 1.0                            0.5
# 4                    1.0                 1.0                            0.0
# ...                  ...                 ...                            ...
# 2296                 1.0                 1.0                            0.5
# 2297                 1.0                 1.0                            0.5
# 2298                 1.0                 1.0                            0.5
# 2299                 1.0                 1.0                            0.5
# 2300                 1.0                 1.0                            0.5
#
# ...

# %%
for x in df:
    print(df[x].value_counts())
    print('-------------------------')
# Out:
# 1.0    1988
# 0.0     313
# Name: Hospital Ownership, dtype: int64
# -------------------------
# 1.0    2262
# 0.0      39
# Name: Emergency Services, dtype: int64
# -------------------------
# 0.5    1601
# 1.0     370
# 0.0     330
# Name: Mortality national comparison, dtype: int64
# -------------------------
# 0.5    948
# 1.0    723
# 0.0    630
# Name: Safety of care national comparison, dtype: int64
# -------------------------
# 0.5    813
# 0.0    754
# 1.0    734
# Name: Readmission national comparison, dtype: int64
# -------------------------
# 0.0    870
# 0.5    768
# 1.0    663
# Name: Patient experience national comparison, dtype: int64
# -------------------------
# 0.5    2034
# 0.0     146
# 1.0     121
# Name: Effectiveness of care national comparison, dtype: int64
# -------------------------
# 0.5    952
# 0.0    812
# 1.0    537
# Name: Timeliness of care national comparison, dtype: int64
# -------------------------
# 0.5    1639
# 1.0     356
# 0.0     306
# ...

# %%
sns.histplot(data=df, x='Hospital overall rating', stat="probability", bins=15)
plt.title("Frequency Distribution of Hospital overall rating in the Data Set")
# Out:
# Text(0.5, 1.0, 'Frequency Distribution of Hospital overall rating in the Data Set')

# %% [markdown]
# ## Correlation matrix

# %%
matrix = df.corr()

# %%
matrix
# Out:
#                                                     Hospital Ownership  \
# Hospital Ownership                                            1.000000
# Emergency Services                                            0.016646
# Mortality national comparison                                 0.104495
# Safety of care national comparison                            0.032532
# Readmission national comparison                              -0.018478
# Patient experience national comparison                        0.002879
# Effectiveness of care national comparison                     0.080424
# Timeliness of care national comparison                       -0.007388
# Efficient use of medical imaging national compa...            0.063396
# Hospital overall rating                                       0.074070
#
#                                                     Emergency Services  \
# Hospital Ownership                                            0.016646
# ...

# %%
sns.heatmap(matrix)
plt.show()

# %% [markdown]
# ## Association between each feature and Hospital overall rating

# %%
for X in df:
    if X != "Hospital overall rating":
        sns.catplot(x=X, y="Hospital overall rating", kind="box", data=df)
